# %%
import pandas as pd

# %%
nov = pd.read_excel("Kalyani_Balance_Sheet_November_2022.xlsx")
nov
# Out:
#                       Name Branch Team member    Department  Fees  Chennai  \
# 0             Thirumurugan            Kalyani  Data Science   499      100
# 1             Harsh Dodiya            Kalyani  Data Science   499      100
# 2             Kunal pahuja            Kalyani  Data Science   499      200
# 3               Arya Singh            Kalyani  Data Science   499      100
# 4          Prashansa Shree            Kalyani  Data Science   499      100
# ..                     ...                ...           ...   ...      ...
# 98          Komal Sharma-K            Kalyani  Data Science   499      100
# 99      Roopal Vashishth-K            Kalyani  Data Science   499      100
# 100          Ashish Sahu-k            Kalyani  Data Science   499      200
# 101  Divya Bhendawadekar-k            Kalyani  Data Science   499      200
# 102      Ben Jose Joseph-k            Kalyani  Data Science   499      100
#
#      Aurangabad  Unnamed: 6 Student Count            Chennai.1  Aurangabad.1  \
# 0           399         NaN           103                15092       36305.0
# 1           399         NaN         Month  2022-11-01 00:00:00           NaN
# 2           299         NaN           NaN                  NaN           NaN
# 3           399         NaN           NaN                  NaN           NaN
# 4           399         NaN           NaN                  NaN           NaN
# ..          ...         ...           ...                  ...           ...
# 98          399         NaN           NaN                  NaN           NaN
# 99          399         NaN           NaN                  NaN           NaN
# 100         299         NaN           NaN                  NaN           NaN
# 101         299         NaN           NaN                  NaN           NaN
# 102         399         NaN           NaN                  NaN           NaN
#
#        Total
# 0    51397.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 98       NaN
# 99       NaN
# 100      NaN
# 101      NaN
# 102      NaN
#
# [103 rows x 11 columns]

# %%
nov = nov.iloc[:,0:6]

# %%
nov
# Out:
#                       Name Branch Team member    Department  Fees  Chennai  \
# 0             Thirumurugan            Kalyani  Data Science   499      100
# 1             Harsh Dodiya            Kalyani  Data Science   499      100
# 2             Kunal pahuja            Kalyani  Data Science   499      200
# 3               Arya Singh            Kalyani  Data Science   499      100
# 4          Prashansa Shree            Kalyani  Data Science   499      100
# ..                     ...                ...           ...   ...      ...
# 98          Komal Sharma-K            Kalyani  Data Science   499      100
# 99      Roopal Vashishth-K            Kalyani  Data Science   499      100
# 100          Ashish Sahu-k            Kalyani  Data Science   499      200
# 101  Divya Bhendawadekar-k            Kalyani  Data Science   499      200
# 102      Ben Jose Joseph-k            Kalyani  Data Science   499      100
#
#      Aurangabad
# 0           399
# 1           399
# 2           299
# 3           399
# 4           399
# ..          ...
# 98          399
# 99          399
# 100         299
# 101         299
# 102         399
#
# [103 rows x 6 columns]

# %%
Aurangabad = nov["Aurangabad"].sum()
Chennai = nov["Chennai"].sum()
print("Total Cash Flow in different Cities:")

a = input("Enter number 1 for Chennai and 2 for Aurangabad")

if a=="1":
    print(f"Total Cash Flow in Chennai in November: {Chennai}")

elif a=="2":
    print(f"Total Cash Flow in Aurangabad in November: {Aurangabad}")
else: 
    print("Wrong Input")
# Out:
# Total Cash Flow in different Cities:
# Enter number 1 for Chennai and 2 for Aurangabad1
# Total Cash Flow in Chennai in November: 15092

# %%
dec = pd.read_excel("Kalyani_Balance_Sheet_December_2022.xlsx")
dec
# Out:
#                           Name Branch Team member    Department  Chennai  \
# 0              Sana Tashfeen-k            Kalyani  Data Science      100
# 1           Yogesh Ujjainkar-k            Kalyani  Data Science      100
# 2       Aishwarya choudhari-k             Kalyani  Data Science      100
# 3             Ashish Mishra-k             Kalyani  Data Science      100
# 4               Vedant satav=k            Kalyani  Data Analyst      200
# ..                         ...                ...           ...      ...
# 118     Sujeet Singh Rajpoot-k            Kalyani  Data Science      100
# 119  Kaligatla Sree Samhitha-K            Kalyani  Data Science      100
# 120         Manuru Sai Suhas-K            Kalyani  Data Science      100
# 121             Harsh Prasad-K            Kalyani  Data Science      100
# 122           Princy Gurnani-K            Kalyani  Data Science      100
#
#      Aurangabad  Fees      Month  Student Count  Chennai.1  Aurangabad.1  \
# 0           399   499 2022-12-01          123.0    16295.0       45082.0
# 1           399   499        NaT            NaN        NaN           NaN
# 2           399   499        NaT            NaN        NaN           NaN
# 3           399   499        NaT            NaN        NaN           NaN
# 4           299   499        NaT            NaN        NaN           NaN
# ..          ...   ...        ...            ...        ...           ...
# 118         399   499        NaT            NaN        NaN           NaN
# 119         399   499        NaT            NaN        NaN           NaN
# 120         399   499        NaT            NaN        NaN           NaN
# 121         399   499        NaT            NaN        NaN           NaN
# 122         399   499        NaT            NaN        NaN           NaN
#
#        Total
# 0    61377.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 118      NaN
# 119      NaN
# 120      NaN
# 121      NaN
# 122      NaN
#
# [123 rows x 11 columns]

# %%
dec = cf_dec.iloc[:, 0:6]
dec
# Out:
#                           Name Branch Team member    Department  Chennai  \
# 0              Sana Tashfeen-k            Kalyani  Data Science      100
# 1           Yogesh Ujjainkar-k            Kalyani  Data Science      100
# 2       Aishwarya choudhari-k             Kalyani  Data Science      100
# 3             Ashish Mishra-k             Kalyani  Data Science      100
# 4               Vedant satav=k            Kalyani  Data Analyst      200
# ..                         ...                ...           ...      ...
# 118     Sujeet Singh Rajpoot-k            Kalyani  Data Science      100
# 119  Kaligatla Sree Samhitha-K            Kalyani  Data Science      100
# 120         Manuru Sai Suhas-K            Kalyani  Data Science      100
# 121             Harsh Prasad-K            Kalyani  Data Science      100
# 122           Princy Gurnani-K            Kalyani  Data Science      100
#
#      Aurangabad  Fees
# 0           399   499
# 1           399   499
# 2           399   499
# 3           399   499
# 4           299   499
# ..          ...   ...
# 118         399   499
# 119         399   499
# 120         399   499
# 121         399   499
# 122         399   499
#
# [123 rows x 6 columns]

# %%
Aurangabad = dec["Aurangabad"].sum()
Chennai = dec["Chennai"].sum()
print("Total Cash Flow in different Cities:")

a = input("Enter number 1 for Chennai and 2 for Aurangabad")

if a=="1":
    print(f"Total Cash Flow in Chennai in November: {Chennai}")

elif a=="2":
    print(f"Total Cash Flow in Aurangabad in November: {Aurangabad}")
else: 
    print("Wrong Input")
# Out:
# Total Cash Flow in different Cities:
# Enter number 1 for Chennai and 2 for Aurangabad1
# Total Cash Flow in Chennai in November: 16295

# %%
import matplotlib.pyplot as plt

# %%
label="Aurangabad","Chennai"
sizes=[Aurangabad,Chennai]
colors=["#e0707c", "#F5DADF"]
explode=(0,0.3)

plt.pie(sizes,explode=explode,labels=label,autopct="%1.1f%%",shadow=True,startangle=90,colors=colors)
plt.title("Stakeholder profile ratio in different cities")
fig = plt.gcf()
fig.set_size_inches(6, 6)
plt.legend()
