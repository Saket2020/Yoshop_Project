# %%
##Write a python program to displayed products count number by products main categories and sub categories.
##Enter 1 put value link = Yoshops.com
##Enter 2 put categories link=
##Output = create excel file with Name Category, Products count,Total products count.

# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.10.0-py3-none-any.whl (6.7 MB)
# Requirement already satisfied: certifi>=2021.10.8 in d:\anaconda\lib\site-packages (from selenium) (2023.5.7)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Collecting trio~=0.17
#   Using cached trio-0.22.0-py3-none-any.whl (384 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in d:\anaconda\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: attrs>=19.2.0 in d:\anaconda\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in d:\anaconda\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting exceptiongroup>=1.0.0rc9
#   Using cached exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting outcome
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: cffi>=1.14 in d:\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting async-generator>=1.9
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\anaconda\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.1.1 h11-0.14.0 outcome-1.2.0 selenium-4.10.0 trio-0.22.0 trio-websocket-0.10.3 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# Set the path to the ChromeDriver executable
webdriver_path = r"C:\Windows\chromedriver.exe"

# Set the service options
service = Service(webdriver_path)

# Create a new instance of the Chrome driver
driver = webdriver.Chrome(service=service)

# Navigate to a website
driver.get("https://yoshops.com")

# Get the page source
page_source = driver.page_source

# Print the page source
print(page_source)
category_names = driver.find_elements(By.XPATH,"//ul[contains(@class, 'nav category-bar')]")
categories = ""
for product in category_names:
    categories = categories + product.text
print(categories)
categories = categories.split('\n')

num_of_cat = len(categories)

def item_details(i):
    product_names = driver.find_elements(By.XPATH,"//span[contains(@class, 'product-title')]")
    print("PRODUCTS IN THIS SUB CATEGORY ARE:")   
    print('\n')
    for product in product_names:
        print(product.text)
        i=i+1
    print('\n')
    print("NUMBER OF PRODUCTS IN THIS SUB CATEGORY IS:",i)
    
def item_number(j):
    product_names = driver.find_elements(By.XPATH,"//span[contains(@class, 'product-title')]")    
    for product in product_names:
        j=j+1
    return j



Category = []
Sub_Category = []
#Number_of_Items_in_Sub_Category = []
number_of_items = []

total_items = 0

driver.get("https://yoshops.com/"+'t/playstation')
categories = 0
#number_of_playstation=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Toys & Games")
Sub_Category.append("Play Station")
#Number_of_Items_in_Sub_Category.append(number_of_playstation)

driver.get("https://yoshops.com/"+'t/drones')
categories = 0
#number_of_drones=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Toys & Games")
Sub_Category.append("Drone")
#Number_of_Items_in_Sub_Category.append(number_of_drones)

driver.get("https://yoshops.com/"+'t/rc-helicopter')
categories = 0
#number_of_rc_helicopter=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Toys & Games")
Sub_Category.append("R C Toys")
#Number_of_Items_in_Sub_Category.append(number_of_rc_helicopter)

driver.get("https://yoshops.com/"+'t/soft-toys')
categories = 0
#number_of_soft_toys=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Toys & Games")
Sub_Category.append("Soft Toys")
#Number_of_Items_in_Sub_Category.append(number_of_soft_toys)


driver.get("https://yoshops.com/"+'t/gaming-accessories')
categories = 0
#number_of_gaming_accessories=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Toys & Games")
Sub_Category.append("Gaming Accessories")
#Number_of_Items_in_Sub_Category.append(number_of_gaming_accessories)
       
driver.get("https://yoshops.com/"+'t/mobile-phones')
categories = 0
#number_of_mobile_phones=item_number(categories)  
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Mobiles")
Sub_Category.append("Mobile Phones")

driver.get("https://yoshops.com/"+'t/smartphones')
categories = 0
#number_of_smartphones=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Mobiles")
Sub_Category.append("Smartphones")

driver.get("https://yoshops.com/"+'t/headphones')
categories = 0
#number_of_headphones=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Mobiles")
Sub_Category.append("Headphones")

driver.get("https://yoshops.com/"+'t/mobiles-accessories')
categories = 0
#number_of_mobiles_accessories=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Mobiles")
Sub_Category.append("Mobile Accessories")

driver.get("https://yoshops.com/"+'t/basic-keypad-phone')
categories = 0
#number_of_basic_keypad_phone=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Mobiles")
Sub_Category.append("Basic Keypad Phones")
            

driver.get("https://yoshops.com/"+'t/gaming-laptops')
categories = 0
#number_of_laptops=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Laptops")
Sub_Category.append("Gaming Laptops")
           

driver.get("https://yoshops.com/"+'t/personal-laptops')
categories = 0
#number_of_personal_laptops=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Laptops")
Sub_Category.append("Personal Laptops")
        
driver.get("https://yoshops.com/"+'t/tablets')
categories = 0
#number_of_tablets=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Laptops")
Sub_Category.append("Tablets")

driver.get("https://yoshops.com/"+'t/laptop-accessories')
categories = 0
#number_of_laptop_accessories=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Laptops")
Sub_Category.append("Laptop Accessories")
            
driver.get("https://yoshops.com/"+'t/computers-accessories')
categories = 0
#number_of_computers_accessories=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Laptops")
Sub_Category.append("Computer Accessories")

#browser.get("https://yoshops.com/"+'t/accessories')
#categories = 0
#number_of_accessories=item_number(categories)

driver.get("https://yoshops.com/"+'t/books')
categories = 0
#number_of_books=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Accessories")
Sub_Category.append("Books")

driver.get("https://yoshops.com/"+'t/stationery')
categories = 0
#number_of_stationery=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Accessories")
Sub_Category.append("Stationary")

driver.get("https://yoshops.com/"+'t/grocery')
categories = 0
#number_of_grocery=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Accessories")
Sub_Category.append("Grocery")

driver.get("https://yoshops.com/"+'t/more')
categories = 0
#number_of_more=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Accessories")
Sub_Category.append("More")

#browser.get("https://yoshops.com/"+'t/electronics')
#categories = 0
#number_of_electronics=item_number(categories)


driver.get("https://yoshops.com/"+'t/led-tv')
categories = 0
#number_of_led_tv=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Electronics")
Sub_Category.append("LED TV")

driver.get("https://yoshops.com/"+'t/jewelry--watches')
categories = 0
#number_of_jewelry_watches=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Electronics")
Sub_Category.append("Jewwlry & Watches")

driver.get("https://yoshops.com/"+'t/irons')
categories = 0
#number_of_irons=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Home & Kitchen")
Sub_Category.append("Iron")


driver.get("https://yoshops.com/"+'t/mixer-grinder-juicer')
categories = 0
#number_of_mixer_grinder_juicer=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Home & Kitchen")
Sub_Category.append("Mixer Grinder Juicer")


driver.get("https://yoshops.com/"+'t/men')
categories = 0
#number_of_men=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Fashion")
Sub_Category.append("Men")

driver.get("https://yoshops.com/"+'t/womens')
categories = 0
#number_of_womens=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Fashion")
Sub_Category.append("Women")

driver.get("https://yoshops.com/"+'t/kids')
categories = 0
#number_of_men=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Fashion")
Sub_Category.append("Kids")


driver.get("https://yoshops.com/"+'t/organic')
categories = 0
#number_of_organic=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Food")
Sub_Category.append("Organic")


driver.get("https://yoshops.com/"+'t/vegetable')
categories = 0
#number_of_vegetable=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Food")
Sub_Category.append("Vegetable")

driver.get("https://yoshops.com/"+'t/non-veg')
categories = 0
#number_of_non_veg=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Food")
Sub_Category.append("Non Vegetable")

driver.get("https://yoshops.com/"+'t/seafood')
categories = 0
#number_of_seafood=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Food")
Sub_Category.append("Seafood")

driver.get("https://yoshops.com/"+'t/biryani')
categories = 0
#number_of_biryani=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Food")
Sub_Category.append("Biriyani")

driver.get("https://yoshops.com/"+'t/tuition')
categories = 0
#number_of_tuition=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Tution")

driver.get("https://yoshops.com/"+'t/internship')
categories = 0
#number_of_internship=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Internships")

driver.get("https://yoshops.com/"+'t/pcd-pharma-distributor')
categories = 0
#number_of_pcd_pharma_distributor=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("PCD Pharma Distributor")

driver.get("https://yoshops.com/"+'t/sponsorship-marketing')
categories = 0
#number_of_sponsorship_marketing=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Sponsorship Marketing")

driver.get("https://yoshops.com/"+'t/refurbished-and-used-laptop-phone')
categories = 0
#number_of_refurbished_used_laptop_phone=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Refurbished & Used Laptop Phone")
              
driver.get("https://yoshops.com/"+'t/bengaluru')
categories = 0
#number_of_bengaluru=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Banglore")
        
driver.get("https://yoshops.com/"+'t/chennai')
categories = 0
#number_of_chennai=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Chennai")

driver.get("https://yoshops.com/"+'t/mumbai')
categories = 0
#number_of_mumbai=item_number(categories)
sub_cat_item_no = item_number(categories)
total_items = total_items +sub_cat_item_no
number_of_items.append(sub_cat_item_no)
Category.append("Services")
Sub_Category.append("Mumbai")

total = ['TOTAL','',total_items]



import pandas as pd
df = pd.DataFrame(list(zip(Category,Sub_Category,number_of_items)),
               columns =['Category', 'Sub Category', 'Number of Items'])
df. loc[39]=total
print(df)



# creating excel writer object
product_file = pd.ExcelWriter('yoshops-excel.xlsx')
# write dataframe to excel
 
df.to_excel(product_file)
 
# save the excel
product_file.save()

# Close the browser
# Out:
# <html><head>
#
#
# <title>Yoshops.com | India's Online Store For Toys And  Electronics Item</title>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta content="text/html; charset=UTF-8" http-equiv="Content-Type">
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport">
#
#
# <meta content="Yoshops.com is online store offer Mobiles,Headphone,Bluetooth Headphone,Sony PlayStation,Earphone,Bags, FMCG Product,Led Tv,Mobile Accessories,Laptop Accesories, FREE SHIPPING,Cash On Delivery,Food,Free Internship,Online Live Classes,Training,RC Toys" name="description">
#
#
#
# <meta content="authenticity_token" name="csrf-param">
#
#
# <meta content="2v1TmNeuiEinQmC6yI3mTZox4QiIEiVT7OtUwt1h5CytmbSZRAo/4UL8GA9SdoZ/LBYWXjeua4pFfdo5KGs1bg==" name="csrf-token">
#
#
#
#
#
#
# <link rel="stylesheet" type="text/css" href="//onlinestore.wsimg.com/assets/themes/__master/assets/stylesheets/master_styles-fefd94f7a32be14cfd662c001f992db70fce90011b6210f3062356f21d61f397.css">
#
#   <link href="//fonts.googleapis.com/css?family=Fauna+One|Open+Sans:400,600" rel="stylesheet" type="text/css">
#
# <link rel="stylesheet" type="text/css" href="/store/a8efe83b-6857-477d-9d0f-f13ca0229a20/theme/asset/008/V1/assets/stylesheets/style-8714825467abcee8fde4fa2fa5493ecc55f39484938abccba60bd60a08606362.css">
#
#
#
#
#
#
#
#
#
#
#
#   <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
#   <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#   <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#     <script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
#   <![endif]-->
#
#
# <script src="https://embed.tawk.to/_s/v4/app/64795e77f7f/js/twk-main.js" charset="UTF-8" crossorigin="*"></script><script src="https://embed.tawk.to/_s/v4/app/64795e77f7f/js/twk-vendor.js" charset="UTF-8" crossorigin="*"></script><script src="https://embed.tawk.to/_s/v4/app/64795e77f7f/js/twk-chunk-vendors.js" charset="UTF-8" crossorigin="*"></script><script src="https://embed.tawk.to/_s/v4/app/64795e77f7f/js/twk-chunk-common.js" charset="UTF-8" crossorigin="*"></script><script src="https://embed.tawk.to/_s/v4/app/64795e77f7f/js/twk-runtime.js" charset="UTF-8" crossorigin="*"></script><script src="https://embed.tawk.to/_s/v4/app/64795e77f7f/js/twk-app.js" charset="UTF-8" crossorigin="*"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202306080101/reactive_library_fy2021.js"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=yoshops.com&amp;callback=_gfp_s_&amp;client=ca-pub-2880440375789047"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202306080101/show_ads_impl_fy2021.js" id="google_shimpl"></script><script type="text/javascript" async="" src="https://cdn.ywxi.net/js/1.js"></script><script type="text/javascript" async="" src="https://static.getbutton.io/widget-send-button/js/init.js"></script><script async="" src="https://embed.tawk.to/5a0424fc198bd56b8c03a242/default" charset="UTF-8" crossorigin="*"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script data-ad-client="ca-pub-2880440375789047" async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" data-checked-head="true"></script>
# <link rel="shortcut icon" href="https://nebula.wsimg.com/obj/RjE0MTAzNDhCNkMzQ0Y1MzE2ODc6OTE1NjYwNTk1ZjA2YmY2NmZkYTY5OWRhZjJjYTJiN2Y6Ojo6OjA=" type="image/x-icon">
#
#
# <script type="text/javascript">
#   var DeferredLoader = (function () {
#
#     function downloadJS(script) {
#       var element = document.createElement("script");
#       element.src = script;
#       document.body.appendChild(element);
#     }
#
#     return {
#       addScript: function (script) {
#         var add = function () {
#           downloadJS(script);
#         };
#
#         if (window.addEventListener) {
#           window.addEventListener("load", add, false);
#         } else if (window.attachEvent) {
#           window.attachEvent("onload", add);
#         } else {
#           window.onload = add;
#         }
#       }
#     };
#   })();
# </script>
#
# <script type="text/javascript">
#   window.currency = {"symbol":"₹","format":"%u%n","with_currency":false,"currency":"INR","decimal_mark":".","thousands_separator":",","precision":2} || {};
# </script>
# <script async="" type="text/javascript" charset="utf-8" src="https://rec.smartlook.com/recorder.js"></script><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=yoshops.com" as="script"><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=yoshops.com"></script><script src="https://rec.smartlook.com/es6/init.98289156c0687ca0da60.js" type="module"></script><script src="https://rec.smartlook.com/es5/init.5a038e524e10aa79eccf.js" nomodule=""></script><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=yoshops.com" as="script"><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=yoshops.com"></script><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=yoshops.com" as="script"><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=yoshops.com"></script><script type="text/javascript" src="https://www.trustedsite.com/rpc/ajax?do=tmjs-visit&amp;host=yoshops.com&amp;rand=1687359322455"></script><style data-styled="active" data-styled-version="5.1.1"></style></head>
#
# <body class="page-home mcafee-enabled" aria-hidden="false" style="">
#   <div class="top-bar">
#     <div class="container">
#       <nav class="navbar navbar-default" role="navigation">
#         <div class="navbar-header">
#           <button type="button" class="navbar-toggle" data-toggle="collapse" data-target="#main-nav">
#           <span class="sr-only">Toggle navigation</span>
#           <span class="icon-bar"></span>
#           <span class="icon-bar"></span>
#           <span class="icon-bar"></span>
#           </button>
#         </div>
#
#
#         <ul class="nav navbar-nav navbar-right" id="cart-info">
#   <li>
#     <a href="/cart" data-ga="checkout_click_cart">
#       <span id="cart-count">View Cart (0 Items)</span>
#     </a>
#   </li>
#   <li id="checkout-link" style="display:none">
#     <a href="/checkout" data-ga="checkout_click_checkout">
#         Checkout
#     </a>
#   </li>
# </ul>
#
#
#
#         <div class="collapse navbar-collapse" id="main-nav">
#         <ul class="nav navbar-nav navbar-right">
#
#
#
#   <li class="dropdown ">
#       <a href="/products" class="dropdown-toggle" data-toggle="dropdown">SHOP <span class="caret"></span></a>
#       <ul class="dropdown-menu" id="nav-cat-list">
#         <li class="view-all "><a href="/products">View All</a></li>
#         <li role="presentation" class="divider"></li>
#
#
#
#
# <li>
#   <a href="/t/toys">Toys &amp; Games</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/mobile-phones">Mobiles</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/laptops">Laptops</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/accessories">Accessories</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/electronics">Electronics</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/home--kitchen">Home &amp; Kitchen</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/fashion">Fashion</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/food">Foods</a>
#
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/Services">Services</a>
#
#
#
# </li>
#
#
#
#
#
#       </ul>
#     </li>
#
#
#
#
#
#   <li class=""><a href="/about">ABOUT US</a></li>
#
#
#
#
#
#   <li class=""><a href="/p/staffing">CAREERS</a></li>
#
#
#
#
#
#   <li class=""><a href="https://yoshops.com/products/franchise-cum-investment-program">FRANCHISE</a></li>
#
#
#
#
#
#   <li class=""><a href="/contact">CONTACT US</a></li>
#
#
#
#
#
#   <li class=""><a target="_blank" href="https://yoshops.com/products/yoshops-referral-gift">REFER &amp; EARN</a></li>
#
#
#
#
#
#   <li class=""><a href="/p/finance">FINANCE</a></li>
#
#
#
#
#
#   <li class=""><a href="https://yoshops.aftership.com/">TRACK Your ORDER</a></li>
#
#
#
#
#
#   <li class=""><a href="/p/return">RETURN</a></li>
#
#
#
#
#
#   <li class="active"><a href="/">HOME</a></li>
#
#
#
# </ul>
#
#         </div>
#       </nav>
#   </div>
# </div>
#
# <div class="container" style="height: auto !important;">
#   <div class="row brand">
#     <div class="col-sm-8">
#
#   <span class="logo"><a href="/"><img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4062_original/:/rs=w:400,h:400" class="img-responsive" alt=" Yoshops.com All Rights Reserved"></a></span>
#
#
#
# 	<span class="tagline">UDYAM-TN-02-0163910</span>
#
#     </div>
#     <div class="col-sm-4">
#       <form class="search" role="search" method="GET" action="/products">
#     <label class="sr-only" for="search">Search</label>
#     <input type="text" class="form-control input-sm" id="search" placeholder="Start your search here" name="keywords">
#     <button class="btn-none"><span class="glyphicon glyphicon-search"></span></button>
# </form>
#     </div>
#   </div><div class="google-auto-placed" style="width: 100%; height: auto; clear: both; text-align: center;"><ins data-ad-format="auto" class="adsbygoogle adsbygoogle-noablate" data-ad-client="ca-pub-2880440375789047" data-adsbygoogle-status="done" style="display: block; margin: 10px auto 20px; background-color: transparent; height: 280px;" data-ad-status="filled"><div id="aswift_1_host" tabindex="0" title="Advertisement" aria-label="Advertisement" style="border: none; height: 280px; width: 940px; margin: 0px; padding: 0px; position: relative; visibility: visible; background-color: transparent; display: inline-block; overflow: visible;"><iframe id="aswift_1" name="aswift_1" style="left:0;position:absolute;top:0;border:0;width:940px;height:280px;" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" width="940" height="280" frameborder="0" marginwidth="0" marginheight="0" vspace="0" hspace="0" allowtransparency="true" scrolling="no" src="https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2880440375789047&amp;output=html&amp;h=280&amp;adk=3414408528&amp;adf=3215562993&amp;pi=t.aa~a.2811506910~rp.4&amp;w=940&amp;fwrn=4&amp;fwrnh=100&amp;lmt=1687359321&amp;rafmt=1&amp;to=qs&amp;pwprc=7790077290&amp;format=940x280&amp;url=https%3A%2F%2Fyoshops.com%2F&amp;fwr=0&amp;pra=3&amp;rpe=1&amp;resp_fmts=3&amp;wgl=1&amp;fa=40&amp;uach=WyJXaW5kb3dzIiwiMTUuMC4wIiwieDg2IiwiIiwiMTE0LjAuNTczNS4xMzQiLFtdLDAsbnVsbCwiNjQiLFtbIk5vdC5BL0JyYW5kIiwiOC4wLjAuMCJdLFsiQ2hyb21pdW0iLCIxMTQuMC41NzM1LjEzNCJdLFsiR29vZ2xlIENocm9tZSIsIjExNC4wLjU3MzUuMTM0Il1dLDBd&amp;dt=1687359320379&amp;bpp=7&amp;bdt=1500&amp;idt=922&amp;shv=r20230615&amp;mjsv=m202306080101&amp;ptt=9&amp;saldr=aa&amp;abxe=1&amp;prev_fmts=0x0&amp;nras=2&amp;correlator=3941481459120&amp;frm=20&amp;pv=1&amp;ga_vid=1297572884.1687359320&amp;ga_sid=1687359321&amp;ga_hid=1641288820&amp;ga_fc=1&amp;u_tz=330&amp;u_his=2&amp;u_h=720&amp;u_w=1280&amp;u_ah=672&amp;u_aw=1280&amp;u_cd=24&amp;u_sd=1.5&amp;dmc=8&amp;adx=40&amp;ady=277&amp;biw=1019&amp;bih=520&amp;scr_x=0&amp;scr_y=0&amp;eid=44759876%2C44759927%2C44759837%2C31075308%2C44788441%2C44794790&amp;oid=2&amp;pvsid=850214029144413&amp;tmod=364692653&amp;uas=0&amp;nvt=1&amp;fc=1920&amp;brdim=10%2C10%2C10%2C10%2C1280%2C0%2C1050%2C652%2C1036%2C520&amp;vis=1&amp;rsz=%7C%7Cs%7C&amp;abl=NS&amp;fu=128&amp;bc=31&amp;ifi=2&amp;uci=a!2&amp;fsb=1&amp;xpc=RvuOAMtKDH&amp;p=https%3A//yoshops.com&amp;dtd=927" data-google-container-id="a!2" data-google-query-id="CKrA7KfP1P8CFc0FXAod56INZA" data-load-complete="true"></iframe></div></ins></div>
#
#
# <ul class="nav category-bar">
#
#
# <li class="dropdown ">
#   <a href="/t/toys">Toys &amp; Games <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/playstation">PlayStation</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/drones">Drones</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/rc-helicopter">RC Toys</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/soft-toys">Soft Toys</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/gaming-accessories">Gaming Accessories</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/mobile-phones">Mobiles <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/smartphones">Smartphones</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/headphones">Headphones</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/mobiles-accessories">Mobiles Accessories</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/basic-keypad-phone">Feature Keypad Mobiles</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/laptops">Laptops <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/gaming-laptops">Gaming Laptops</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/personal-laptops">Personal Laptops</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/tablets">Tablets</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/laptop-accessories">Laptop Accessories</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/computers-accessories">Computers Accessories</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/accessories">Accessories <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/books">Books</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/stationery">Stationery</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/books--bags">Bags</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/grocery">SpareParts</a>
#
#
#     <ul>
#
#
# <li>
#   <a href="/t/bike">Auto spare parts</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/Mobile-Parts">Mobile Spare Parts</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/Laptop-spare-parts">Laptop spare parts</a>
#
# </li>
#
#
#     </ul>
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/more">More</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/electronics">Electronics <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/led-tv">Led TV</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/jewelry--watches">Others</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/home--kitchen">Home &amp; Kitchen <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/irons">Irons</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/mixer-grinder-juicer">Mixer Grinder Juicer</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/fashion">Fashion <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/men">Men</a>
#
#
#     <ul>
#
#
# <li>
#   <a href="/t/men-clothing">Men Clothing</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/sunglasses">Sunglasses</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/watches">Watches</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/mens-footwear">Men's Footwear</a>
#
# </li>
#
#
#     </ul>
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/womens">Womens</a>
#
#
#     <ul>
#
#
# <li>
#   <a href="/t/women-clothing">Women Clothing</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/face-makeup">Face Makeup</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/personal-care">Personal Care</a>
#
# </li>
#
#
#     </ul>
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/kids">Kids</a>
#
#
#     <ul>
#
#
# <li>
#   <a href="/t/kids-clothing">Kids Clothing</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/shoes">Shoes</a>
#
# </li>
#
#
#     </ul>
#
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/food">Foods <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/organic">Organic foods</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/vegetable">Vegetable</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/non-veg">Non Veg</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/seafood">Seafood</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/biryani">Biryani</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
#
# <li class="dropdown ">
#   <a href="/t/Services">Services <span class="caret"></span></a>
#     <ul class="dropdown-menu">
#
#
# <li>
#   <a href="/t/tuition">Online Live Tuition</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/internship">Training Internship Work From Home</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/pcd-pharma-distributor">Yoga Pharma Franchise</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/sponsorship-marketing">Sponsorship Marketing</a>
#
#
#     <ul>
#
#
# <li>
#   <a href="/t/teacher-sponsorship">Teacher Sponsorship</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/blog-sponsorship">Blog Sponsorship</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/instagram-sponsorship">Instagram Sponsorship</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/youtuber-sponsorship">YouTube Sponsorship</a>
#
# </li>
#
#
#     </ul>
#
#
# </li>
#
#
#
# <li>
#   <a href="/t/refurbished-and-used-laptop-phone">Refurbish Laptop Mobiles</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/bengaluru">Bengaluru</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/chennai">Chennai</a>
#
# </li>
#
#
#
# <li>
#   <a href="/t/mumbai">Mumbai</a>
#
# </li>
#
#
#     </ul>
# </li>
#
#
#
# </ul>
#
#
#
#   <div class="content" style="height: auto !important; min-height: 0px !important;">
#
# <div class="row">
#   <div class="col-sm-12">
#     <div class="hero">
#       <div id="slider-ph" style="display: none;"></div>
#       <div class="bx-wrapper" style="max-width: 100%;"><div class="bx-viewport" style="width: 100%; overflow: hidden; position: relative; height: 313px;"><ul class="bxslider slider" style="width: auto; position: relative;">
#
#
#
#
# <li style="float: none; list-style: none; position: absolute; width: 940px; z-index: 50; display: block;">
#   <a href="https://yoshops.com/products/free-demo-class-live-tuitions-for-std1-to-12th-std-cbse-board-in-india">
#     <div class="image-wrapper">
#       <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4226_original/:/cr=t:17.875,l:0,w:1040,h:346.125/rs=w:1200,h:1200" data-hook="image" class="hero-img">
#     </div>
#
#     <div class="hero-text-position">
#       <div class="hero-text-table">
#         <div class="hero-text-cell">
#           <div class="hero-overlay">
#
#             <div class="hero-text" id="hero-text" data-empty-hide="overlay_text" data-hook="overlay_text" style="display:none"></div>
#
#             <div class="hero-button" data-empty-hide="button_text">
#               <button id="hero-button" class="btn btn-primary" data-hook="button_text">BOOK NOW</button>
#             </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </a>
# </li>
#
#
#
# <li style="float: none; list-style: none; position: absolute; width: 940px; z-index: 0; display: none;">
#   <a href="https://yoshops.com/t/internship">
#     <div class="image-wrapper">
#       <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4092_original/:/cr=t:0,l:0,w:860,h:286.21875/rs=w:1200,h:1200" data-hook="image" class="hero-img">
#     </div>
#
#     <div class="hero-text-position">
#       <div class="hero-text-table">
#         <div class="hero-text-cell">
#           <div class="hero-overlay">
#
#             <div class="hero-text" id="hero-text" data-empty-hide="overlay_text" data-hook="overlay_text" style="display:none"></div>
#
#             <div class="hero-button" data-empty-hide="button_text">
#               <button id="hero-button" class="btn btn-primary" data-hook="button_text">Apply Now</button>
#             </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </a>
# </li>
#
#
#
# <li style="float: none; list-style: none; position: absolute; width: 940px; z-index: 0; display: none;">
#   <a href="https://upstox.com/open-account/?f=ND0V">
#     <div class="image-wrapper">
#       <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3253_original/:/cr=t:21.196875000000002,l:0,w:714,h:237.628125/rs=w:1200,h:1200" data-hook="image" class="hero-img">
#     </div>
#
#     <div class="hero-text-position">
#       <div class="hero-text-table">
#         <div class="hero-text-cell">
#           <div class="hero-overlay">
#
#             <div class="hero-text" id="hero-text" data-empty-hide="overlay_text" data-hook="overlay_text" style="display:none"></div>
#
#             <div class="hero-button" data-empty-hide="button_text">
#               <button id="hero-button" class="btn btn-primary" data-hook="button_text">OPEN NOW</button>
#             </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </a>
# </li>
#
#
#
# <li style="float: none; list-style: none; position: absolute; width: 940px; z-index: 0; display: none;">
#   <a href="/products/">
#     <div class="image-wrapper">
#       <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4227_original/:/cr=t:16.25,l:0,w:1040,h:346.125/rs=w:1200,h:1200" data-hook="image" class="hero-img">
#     </div>
#
#     <div class="hero-text-position">
#       <div class="hero-text-table">
#         <div class="hero-text-cell">
#           <div class="hero-overlay">
#
#             <div class="hero-text" id="hero-text" data-empty-hide="overlay_text" data-hook="overlay_text" style="display:none"></div>
#
#             <div class="hero-button" data-empty-hide="button_text">
#               <button id="hero-button" class="btn btn-primary" data-hook="button_text">SHOP NOW</button>
#             </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </a>
# </li>
#
#
#       </ul></div><div class="bx-controls bx-has-pager"><div class="bx-pager bx-default-pager"><div class="bx-pager-item"><a href="" data-slide-index="0" class="bx-pager-link active">1</a></div><div class="bx-pager-item"><a href="" data-slide-index="1" class="bx-pager-link">2</a></div><div class="bx-pager-item"><a href="" data-slide-index="2" class="bx-pager-link">3</a></div><div class="bx-pager-item"><a href="" data-slide-index="3" class="bx-pager-link">4</a></div></div></div></div>
#     </div>
#   </div>
# </div>
#
#
#
#
#
#
# <div class="products featured-products" style="height: auto !important;">
#   <div class="row products-title">
#     <div class="col-sm-12">
#       <h2><span>Featured Products</span></h2>
#     </div>
#   </div>
#   <div class="row" style="height: auto !important;">
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/jiobook-laptop-29-46-cm-11-6-inch-1-2-kg-nb2112qb-jioos-octa-core-lte-2gb-lpddr4x-32gb-emmc-hd">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4132_original/:/rs=w:600,h:600" alt="JioBook Laptop 29.46 cm (11.6 inch) 1.2 Kg With Free HRX Men Orange Printed Cotton T-shirt">
#         </div>
#       </div>
#       <span class="product-title" href="/products/jiobook-laptop-29-46-cm-11-6-inch-1-2-kg-nb2112qb-jioos-octa-core-lte-2gb-lpddr4x-32gb-emmc-hd">JioBook Laptop 29.46 cm (11.6 inch) 1.2 Kg With Free HRX Men Orange Printed Cotton T-shirt</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>35,605.00</span><span><span class="rupee">₹</span>16,779.00</span></div>
#
#
#       <div class="free-shipping">
#   <div class="ship-table">
#     <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="6.943 12.685 20 14" enable-background="new 6.943 12.685 20 14" xml:space="preserve">
#     <path display="none" d="M39.451,34.034c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       s1.578-3.611,3.611-3.611S39.451,32.002,39.451,34.034z M35.612,32.002c-1.13,0-1.806,0.902-1.806,1.805s0.902,1.806,1.806,1.806
#       c1.13,0,1.806-0.903,1.806-1.806S36.742,32.002,35.612,32.002z"></path>
#     <rect x="6.938" y="13.03" display="none" width="20.322" height="15.581"></rect>
#     <path display="none" d="M17.999,33.58c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       c0-2.033,1.579-3.611,3.611-3.611S17.999,31.547,17.999,33.58z M14.388,31.773c-1.13,0-1.806,0.903-1.806,1.807
#       c0,0.902,0.903,1.805,1.806,1.805s1.806-0.902,1.806-1.805C16.193,32.677,15.291,31.773,14.388,31.773z"></path>
#     <path display="none" d="M28.384,34.255V19.356V17.55h8.358c0,0,6.32,0.455,6.32,6.32v8.579l-1.357,1.578h-0.903
#       c0,0,0.454-5.644-5.417-5.644c0,0-5.195-0.228-5.195,5.644h-1.806V34.255z M37.19,19.804c-2.708,0-4.065,0-4.065,0v3.384h5.645
#       h1.805C40.581,23.194,39.678,19.804,37.19,19.804z"></path>
#     <path display="none" d="M6.938,29.969h3.611c0,0-1.806,1.805-1.578,4.293H6.938V29.969z"></path>
#     <path display="none" d="M27.26,29.969h-9.034c0,0,1.806,1.805,1.578,4.293h7.45v-4.293H27.26z"></path>
#     <path d="M10.976,22.635c1.119,0,2.025,0.907,2.025,2.026c0,1.119-0.906,2.025-2.025,2.025c-1.118,0-2.029-0.902-2.029-2.025
#       C8.946,23.542,9.857,22.635,10.976,22.635z M9.927,24.661c0,0.578,0.468,1.048,1.049,1.048c0.582,0,1.049-0.466,1.049-1.048
#       c0-0.578-0.468-1.05-1.049-1.05C10.395,23.611,9.927,24.083,9.927,24.661z"></path>
#     <rect x="15.703" y="12.685" width="11.24" height="8.974"></rect>
#     <path d="M22.857,22.635c1.119,0,2.026,0.907,2.026,2.026c0,1.119-0.907,2.025-2.026,2.025c-1.118,0-2.026-0.906-2.026-2.025
#       C20.832,23.542,21.739,22.635,22.857,22.635z M21.808,24.661c0,0.577,0.467,1.048,1.049,1.048c0.577,0,1.05-0.468,1.05-1.048
#       c0-0.581-0.469-1.05-1.05-1.05C22.279,23.611,21.808,24.08,21.808,24.661z"></path>
#     <path d="M13.956,24.813c0-3.235-2.863-3.155-2.863-3.155c-3.294,0-2.979,3.155-2.979,3.155H7.682l-0.738-0.936v-4.77
#       c0-3.254,3.469-3.565,3.469-3.565h4.6v0.995v8.28h-1.057V24.813z M8.318,18.658h0.955h3.155v-1.89c0,0-0.684,0-2.219,0
#       C8.727,16.771,8.318,18.658,8.318,18.658z"></path>
#     <path d="M26.943,22.416h-1.959c0,0,1.032,1.005,0.853,2.409h1.106V22.416z"></path>
#     <path d="M15.703,22.416h5.009c0,0-1.032,1.005-0.852,2.409h-4.157V22.416z"></path>
#     </svg>
#     <span>Free Shipping!</span>
#   </div>
# </div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="582" data-name="JioBook Laptop 29.46 cm (11.6 inch) 1.2 Kg With Free HRX Men Orange Printed Cotton T-shirt" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Fjiobook-laptop-29-46-cm-11-6-inch-1-2-kg-nb2112qb-jioos-octa-core-lte-2gb-lpddr4x-32gb-emmc-hd" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F4132_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/jiophone-smartphone-next-32-gb-2-gb-ram-black">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4032_original/:/rs=w:600,h:600" alt="JioPhone Smartphone Next 32 GB, 2 GB RAM, Black">
#         </div>
#       </div>
#       <span class="product-title" href="/products/jiophone-smartphone-next-32-gb-2-gb-ram-black">JioPhone Smartphone Next 32 GB, 2 GB RAM, Black</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>8,500.00</span><span><span class="rupee">₹</span>6,499.00</span></div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="573" data-name="JioPhone Smartphone Next 32 GB, 2 GB RAM, Black" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Fjiophone-smartphone-next-32-gb-2-gb-ram-black" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F4032_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/data-science-training-program-with-real-time-project">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3985_original/:/rs=w:600,h:600" alt="Data Science Training Program With Real Time Project">
#         </div>
#       </div>
#       <span class="product-title" href="/products/data-science-training-program-with-real-time-project">Data Science Training Program With Real Time Project</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>5,745.00</span><span><span class="rupee">₹</span>499.00</span></div>
#
#
#       <div class="free-shipping">
#   <div class="ship-table">
#     <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="6.943 12.685 20 14" enable-background="new 6.943 12.685 20 14" xml:space="preserve">
#     <path display="none" d="M39.451,34.034c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       s1.578-3.611,3.611-3.611S39.451,32.002,39.451,34.034z M35.612,32.002c-1.13,0-1.806,0.902-1.806,1.805s0.902,1.806,1.806,1.806
#       c1.13,0,1.806-0.903,1.806-1.806S36.742,32.002,35.612,32.002z"></path>
#     <rect x="6.938" y="13.03" display="none" width="20.322" height="15.581"></rect>
#     <path display="none" d="M17.999,33.58c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       c0-2.033,1.579-3.611,3.611-3.611S17.999,31.547,17.999,33.58z M14.388,31.773c-1.13,0-1.806,0.903-1.806,1.807
#       c0,0.902,0.903,1.805,1.806,1.805s1.806-0.902,1.806-1.805C16.193,32.677,15.291,31.773,14.388,31.773z"></path>
#     <path display="none" d="M28.384,34.255V19.356V17.55h8.358c0,0,6.32,0.455,6.32,6.32v8.579l-1.357,1.578h-0.903
#       c0,0,0.454-5.644-5.417-5.644c0,0-5.195-0.228-5.195,5.644h-1.806V34.255z M37.19,19.804c-2.708,0-4.065,0-4.065,0v3.384h5.645
#       h1.805C40.581,23.194,39.678,19.804,37.19,19.804z"></path>
#     <path display="none" d="M6.938,29.969h3.611c0,0-1.806,1.805-1.578,4.293H6.938V29.969z"></path>
#     <path display="none" d="M27.26,29.969h-9.034c0,0,1.806,1.805,1.578,4.293h7.45v-4.293H27.26z"></path>
#     <path d="M10.976,22.635c1.119,0,2.025,0.907,2.025,2.026c0,1.119-0.906,2.025-2.025,2.025c-1.118,0-2.029-0.902-2.029-2.025
#       C8.946,23.542,9.857,22.635,10.976,22.635z M9.927,24.661c0,0.578,0.468,1.048,1.049,1.048c0.582,0,1.049-0.466,1.049-1.048
#       c0-0.578-0.468-1.05-1.049-1.05C10.395,23.611,9.927,24.083,9.927,24.661z"></path>
#     <rect x="15.703" y="12.685" width="11.24" height="8.974"></rect>
#     <path d="M22.857,22.635c1.119,0,2.026,0.907,2.026,2.026c0,1.119-0.907,2.025-2.026,2.025c-1.118,0-2.026-0.906-2.026-2.025
#       C20.832,23.542,21.739,22.635,22.857,22.635z M21.808,24.661c0,0.577,0.467,1.048,1.049,1.048c0.577,0,1.05-0.468,1.05-1.048
#       c0-0.581-0.469-1.05-1.05-1.05C22.279,23.611,21.808,24.08,21.808,24.661z"></path>
#     <path d="M13.956,24.813c0-3.235-2.863-3.155-2.863-3.155c-3.294,0-2.979,3.155-2.979,3.155H7.682l-0.738-0.936v-4.77
#       c0-3.254,3.469-3.565,3.469-3.565h4.6v0.995v8.28h-1.057V24.813z M8.318,18.658h0.955h3.155v-1.89c0,0-0.684,0-2.219,0
#       C8.727,16.771,8.318,18.658,8.318,18.658z"></path>
#     <path d="M26.943,22.416h-1.959c0,0,1.032,1.005,0.853,2.409h1.106V22.416z"></path>
#     <path d="M15.703,22.416h5.009c0,0-1.032,1.005-0.852,2.409h-4.157V22.416z"></path>
#     </svg>
#     <span>Free Shipping!</span>
#   </div>
# </div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="567" data-name="Data Science Training Program With Real Time Project" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Fdata-science-training-program-with-real-time-project" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F3985_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/data-analyst-training-program-with-real-time-project1">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3987_original/:/rs=w:600,h:600" alt="Data Analyst Training Program With Real Time Project">
#         </div>
#       </div>
#       <span class="product-title" href="/products/data-analyst-training-program-with-real-time-project1">Data Analyst Training Program With Real Time Project</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>5,745.00</span><span><span class="rupee">₹</span>499.00</span></div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="568" data-name="Data Analyst Training Program With Real Time Project" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Fdata-analyst-training-program-with-real-time-project1" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F3987_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/lkg-to-pg-online-tuition-at-monthly-fees-rs-499">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4241_original/:/rs=w:600,h:600" alt="LKG to PG Online Tuition at monthly fees Rs.499">
#         </div>
#       </div>
#       <span class="product-title" href="/products/lkg-to-pg-online-tuition-at-monthly-fees-rs-499">LKG to PG Online Tuition at monthly fees Rs.499</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>2,500.00</span><span><span class="rupee">₹</span>499.00</span></div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="603" data-name="LKG to PG Online Tuition at monthly fees Rs.499" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Flkg-to-pg-online-tuition-at-monthly-fees-rs-499" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F4241_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/hrx-by-hrithik-roshan-men-orange-printed-cotton-t-shirt-with-yoshops-free-gift-hear-phone-pouch">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4055_original/:/rs=w:600,h:600" alt="HRX by Hrithik Roshan Men Orange Printed Cotton T-shirt With Yoshops Free Gift Hear phone Pouch">
#         </div>
#       </div>
#       <span class="product-title" href="/products/hrx-by-hrithik-roshan-men-orange-printed-cotton-t-shirt-with-yoshops-free-gift-hear-phone-pouch">HRX by Hrithik Roshan Men Orange Printed Cotton T-shirt With Yoshops Free Gift Hear phone Pouch</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>899.00</span><span><span class="rupee">₹</span>329.00</span></div>
#
#
#       <div class="free-shipping">
#   <div class="ship-table">
#     <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="6.943 12.685 20 14" enable-background="new 6.943 12.685 20 14" xml:space="preserve">
#     <path display="none" d="M39.451,34.034c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       s1.578-3.611,3.611-3.611S39.451,32.002,39.451,34.034z M35.612,32.002c-1.13,0-1.806,0.902-1.806,1.805s0.902,1.806,1.806,1.806
#       c1.13,0,1.806-0.903,1.806-1.806S36.742,32.002,35.612,32.002z"></path>
#     <rect x="6.938" y="13.03" display="none" width="20.322" height="15.581"></rect>
#     <path display="none" d="M17.999,33.58c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       c0-2.033,1.579-3.611,3.611-3.611S17.999,31.547,17.999,33.58z M14.388,31.773c-1.13,0-1.806,0.903-1.806,1.807
#       c0,0.902,0.903,1.805,1.806,1.805s1.806-0.902,1.806-1.805C16.193,32.677,15.291,31.773,14.388,31.773z"></path>
#     <path display="none" d="M28.384,34.255V19.356V17.55h8.358c0,0,6.32,0.455,6.32,6.32v8.579l-1.357,1.578h-0.903
#       c0,0,0.454-5.644-5.417-5.644c0,0-5.195-0.228-5.195,5.644h-1.806V34.255z M37.19,19.804c-2.708,0-4.065,0-4.065,0v3.384h5.645
#       h1.805C40.581,23.194,39.678,19.804,37.19,19.804z"></path>
#     <path display="none" d="M6.938,29.969h3.611c0,0-1.806,1.805-1.578,4.293H6.938V29.969z"></path>
#     <path display="none" d="M27.26,29.969h-9.034c0,0,1.806,1.805,1.578,4.293h7.45v-4.293H27.26z"></path>
#     <path d="M10.976,22.635c1.119,0,2.025,0.907,2.025,2.026c0,1.119-0.906,2.025-2.025,2.025c-1.118,0-2.029-0.902-2.029-2.025
#       C8.946,23.542,9.857,22.635,10.976,22.635z M9.927,24.661c0,0.578,0.468,1.048,1.049,1.048c0.582,0,1.049-0.466,1.049-1.048
#       c0-0.578-0.468-1.05-1.049-1.05C10.395,23.611,9.927,24.083,9.927,24.661z"></path>
#     <rect x="15.703" y="12.685" width="11.24" height="8.974"></rect>
#     <path d="M22.857,22.635c1.119,0,2.026,0.907,2.026,2.026c0,1.119-0.907,2.025-2.026,2.025c-1.118,0-2.026-0.906-2.026-2.025
#       C20.832,23.542,21.739,22.635,22.857,22.635z M21.808,24.661c0,0.577,0.467,1.048,1.049,1.048c0.577,0,1.05-0.468,1.05-1.048
#       c0-0.581-0.469-1.05-1.05-1.05C22.279,23.611,21.808,24.08,21.808,24.661z"></path>
#     <path d="M13.956,24.813c0-3.235-2.863-3.155-2.863-3.155c-3.294,0-2.979,3.155-2.979,3.155H7.682l-0.738-0.936v-4.77
#       c0-3.254,3.469-3.565,3.469-3.565h4.6v0.995v8.28h-1.057V24.813z M8.318,18.658h0.955h3.155v-1.89c0,0-0.684,0-2.219,0
#       C8.727,16.771,8.318,18.658,8.318,18.658z"></path>
#     <path d="M26.943,22.416h-1.959c0,0,1.032,1.005,0.853,2.409h1.106V22.416z"></path>
#     <path d="M15.703,22.416h5.009c0,0-1.032,1.005-0.852,2.409h-4.157V22.416z"></path>
#     </svg>
#     <span>Free Shipping!</span>
#   </div>
# </div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="578" data-name="HRX by Hrithik Roshan Men Orange Printed Cotton T-shirt With Yoshops Free Gift Hear phone Pouch" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Fhrx-by-hrithik-roshan-men-orange-printed-cotton-t-shirt-with-yoshops-free-gift-hear-phone-pouch" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F4055_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6">
#   <div class="product">
#     <a class="product-link" href="/products/zebronics-saga-portable-bluetooth-wireless-speaker">
#       <div class="product-thumb">
#         <div class="product-thumb-inner">
#           <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1309_original/:/rs=w:600,h:600" alt="Zebronics SAGA Portable Bluetooth wireless speaker">
#         </div>
#       </div>
#       <span class="product-title" href="/products/zebronics-saga-portable-bluetooth-wireless-speaker">Zebronics SAGA Portable Bluetooth wireless speaker</span>
#     </a>
#
#     <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>599.00</span><span><span class="rupee">₹</span>559.00</span></div>
#
#
#       <div class="free-shipping">
#   <div class="ship-table">
#     <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="6.943 12.685 20 14" enable-background="new 6.943 12.685 20 14" xml:space="preserve">
#     <path display="none" d="M39.451,34.034c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       s1.578-3.611,3.611-3.611S39.451,32.002,39.451,34.034z M35.612,32.002c-1.13,0-1.806,0.902-1.806,1.805s0.902,1.806,1.806,1.806
#       c1.13,0,1.806-0.903,1.806-1.806S36.742,32.002,35.612,32.002z"></path>
#     <rect x="6.938" y="13.03" display="none" width="20.322" height="15.581"></rect>
#     <path display="none" d="M17.999,33.58c0,2.032-1.578,3.61-3.611,3.61s-3.611-1.578-3.611-3.61
#       c0-2.033,1.579-3.611,3.611-3.611S17.999,31.547,17.999,33.58z M14.388,31.773c-1.13,0-1.806,0.903-1.806,1.807
#       c0,0.902,0.903,1.805,1.806,1.805s1.806-0.902,1.806-1.805C16.193,32.677,15.291,31.773,14.388,31.773z"></path>
#     <path display="none" d="M28.384,34.255V19.356V17.55h8.358c0,0,6.32,0.455,6.32,6.32v8.579l-1.357,1.578h-0.903
#       c0,0,0.454-5.644-5.417-5.644c0,0-5.195-0.228-5.195,5.644h-1.806V34.255z M37.19,19.804c-2.708,0-4.065,0-4.065,0v3.384h5.645
#       h1.805C40.581,23.194,39.678,19.804,37.19,19.804z"></path>
#     <path display="none" d="M6.938,29.969h3.611c0,0-1.806,1.805-1.578,4.293H6.938V29.969z"></path>
#     <path display="none" d="M27.26,29.969h-9.034c0,0,1.806,1.805,1.578,4.293h7.45v-4.293H27.26z"></path>
#     <path d="M10.976,22.635c1.119,0,2.025,0.907,2.025,2.026c0,1.119-0.906,2.025-2.025,2.025c-1.118,0-2.029-0.902-2.029-2.025
#       C8.946,23.542,9.857,22.635,10.976,22.635z M9.927,24.661c0,0.578,0.468,1.048,1.049,1.048c0.582,0,1.049-0.466,1.049-1.048
#       c0-0.578-0.468-1.05-1.049-1.05C10.395,23.611,9.927,24.083,9.927,24.661z"></path>
#     <rect x="15.703" y="12.685" width="11.24" height="8.974"></rect>
#     <path d="M22.857,22.635c1.119,0,2.026,0.907,2.026,2.026c0,1.119-0.907,2.025-2.026,2.025c-1.118,0-2.026-0.906-2.026-2.025
#       C20.832,23.542,21.739,22.635,22.857,22.635z M21.808,24.661c0,0.577,0.467,1.048,1.049,1.048c0.577,0,1.05-0.468,1.05-1.048
#       c0-0.581-0.469-1.05-1.05-1.05C22.279,23.611,21.808,24.08,21.808,24.661z"></path>
#     <path d="M13.956,24.813c0-3.235-2.863-3.155-2.863-3.155c-3.294,0-2.979,3.155-2.979,3.155H7.682l-0.738-0.936v-4.77
#       c0-3.254,3.469-3.565,3.469-3.565h4.6v0.995v8.28h-1.057V24.813z M8.318,18.658h0.955h3.155v-1.89c0,0-0.684,0-2.219,0
#       C8.727,16.771,8.318,18.658,8.318,18.658z"></path>
#     <path d="M26.943,22.416h-1.959c0,0,1.032,1.005,0.853,2.409h1.106V22.416z"></path>
#     <path d="M15.703,22.416h5.009c0,0-1.032,1.005-0.852,2.409h-4.157V22.416z"></path>
#     </svg>
#     <span>Free Shipping!</span>
#   </div>
# </div>
#
#
#
#     <div class="review-wrapper">
#       <div class="single-product-review">
#         <div class="yotpo bottomLine" style="display:inline-block; width:auto;" data-appkey="blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb" data-domain="https://yoshops.com" data-product-id="193" data-name="Zebronics SAGA Portable Bluetooth wireless speaker" data-url="https%3A%2F%2Fyoshops.com%2Fproducts%2Fzebronics-saga-portable-bluetooth-wireless-speaker" data-image-url="https%3A%2F%2Fisteam.wsimg.com%2Fip%2Fa8efe83b-6857-477d-9d0f-f13ca0229a20%2Fols%2F1309_original%2F%3A%2Frs%3Dw%3A600%2Ch%3A600">
# </div>
#
#       </div>
#     </div>
#
#  </div>
# </div>
#
#
#
#
# <div class="col-sm-3 col-xs-6" style="height: auto !important; min-height: 0px !important;">
# ...
#
#     // Payment page
#     'checkout_payment_click_edit_shipping_address': ['nemo-storefront-checkout-payment', 'click-edit-shipping-address'],
#     'checkout_payment_click_edit_billing_address': ['nemo-storefront-checkout-payment', 'click-edit-billing-address'],
#     'checkout_payment_click_payment_method_radio_option': ['nemo-storefront-checkout-payment', 'click-payment-method-radio-option'],
#     'checkout_payment_click_place_order': ['nemo-storefront-checkout-payment', 'click-place-order'],
#     'checkout_payment_click_check_out_with_paypal_button': ['nemo-storefront-checkout-payment', 'click-check-out-with-paypal-button'],
#     'checkout_payment_click_check_out_with_mercado_pago_button': ['nemo-storefront-checkout-payment', 'click-check-out-with-mercado-pago-button'],
#     'checkout_payment_click_finalize_paypal_redirect_button': ['nemo-storefront-checkout-payment', 'click-finalize-paypal-redirect-button'],
#     'checkout_payment_click_apply_coupon': ['nemo-storefront-checkout-payment', 'click-apply-coupon'],
#     'checkout_payment_receive_stripe_error': ['nemo-storefront-checkout-payment', 'receive-stripe-error'],
#
#     // Confirm page
#     'checkout_confirm_click_return_to_store': ['nemo-storefront-checkout-confirm', 'click-return-to-store'],
#     'checkout_confirm_click_contact_us': ['nemo-storefront-checkout-confirm', 'click-contact-us']
#
#     // END checkout events
#   };
#
#   // Make the object immutable
#   Object.freeze(window.sfEventMap);
# </script>
#
#
# <script type="text/javascript">
#   window.VISIBILITY_ANIMATION_SPEED = 300;
#   // Add GA to global cart icon and checkout link with JS since both are in unique files for every theme (i.e. due to laziness).
#   // However, theme 010 has a different header structure, so the data-ga label for the checkout link was added onto the element in the liquid file.
#   var $cartIcon = $('a#cart-info[href="/cart"]');
#   var $cartIconWrapper;
#
#   if ($cartIcon && $cartIcon.length) {
#     $cartIcon.attr('data-ga', 'checkout_click_cart');
#   } else {
#     $cartIconWrapper = $('#cart-info');
#     $cartIconWrapper.find('a[href="/cart"]').attr('data-ga', 'checkout_click_cart');
#     $cartIconWrapper.find('a[href="/checkout"]').attr('data-ga', 'checkout_click_checkout');
#   }
#
#   // START Google Analytics
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   // Create GA tracker for Nemo Product Manager to track the storefront
#   ga('create', 'UA-85190973-1', 'auto', 'nemoPmTracker');
#
#
#     // Create GA tracker for merchant
#     ga('create', 'UA-87949983-1', 'auto', {
#       name: 'merchantTracker',
#       allowLinker: true
#     });
#     ga('merchantTracker.require', 'linker'); // Load the plugin.
#     ga('merchantTracker.linker:autoLink', ['yoshops.com', 'mysimplestore.com']); // Define which domains to autoLink.
#     ga('merchantTracker.send', 'pageview');
#
#
#   window.trackEvent = function (eventKey, label) {
#     if (typeof window.sfEventMap !== 'undefined') {
#       var eventValue = window.sfEventMap[eventKey];
#
#       if (!eventValue) {
#         return;
#       }
#
#       ga('nemoPmTracker.send', {
#         hitType: 'event',
#         eventCategory: eventValue[0],
#         eventAction: eventValue[1],
#         eventLabel: label
#       });
#     }
#   };
#
#   window.trackPageview = function (pagePath) {
#     if (!pagePath) {
#       return;
#     }
#
#     ga('nemoPmTracker.send', {
#       hitType: 'pageview',
#       page: pagePath
#     });
#   };
#   // END Google Analytics
#
#     if ($) {
#       // Listener for GA
#       $(document).ready(function () {
#         $(document).on('click', '[data-ga], [data-ga][data-ga-label]', function () {
#           var key = $(this).attr('data-ga');
#           var label = $(this).attr('data-ga-label');
#           window.trackEvent(key, label);
#         });
#       });
#
#       // GA: Track pageview for checkout pages and order confirmation page
#
#
#       // GA: Track error event in checkout
#
#
#       $.ajaxSetup({
#           headers: {
#               'X-CSRF-Token': $('meta[name="csrf-token"]').attr('content')
#           }
#       });
#
#
#
#
#       // Cart remove logic
#       $(document).on('click', '.cart-remove', function () {
#           var $form = $(this).closest('form'),
#               $quantity = $(this).closest('tr').find('.cart-quantity');
#
#           $('.cart-remove').addClass('cart-remove-disable')
#           $form.find('button').attr('disabled', 'disabled');
#           $quantity.val(0);
#           $form.submit();
#       });
#
#       // Attach a submit handler to the contact form
#       $(document).on('submit', '#contact-form', function (event) {
#           //Stop normal form submision
#           event.preventDefault();
#           var formData =  $('#contact-form').serialize();
#
#           Nemo.submitFormData({
#               data: formData,
#               method: "POST",
#               always: function (res) {
#                   if (res) {
#                       $('#contact-form-box').replaceWith(res);
#                   }
#               }
#           });
#
#           return false;
#       });
#     }
# </script>
#
#
#
# <script type="text/javascript" src="//onlinestore.wsimg.com/assets/themes/__master/assets/javascripts/lib/jquery.cookie-e9703d26744209e6a8c89c89a2b129f1c860fd708a1d958f6a6056c79b82ccb3.js"></script>
#
# <script type="text/javascript">DeferredLoader.addScript("//staticw2.yotpo.com/blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb/widget.js");</script>
#
#
#
#   <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2292_original/:/rs=w:800,h:800" style="box-sizing: border-box; border: 0px none; max-width: 100%; height: 144.601px; width: 332.583px;">
# <div class="as-track-button" data-size="normal" data-domain="yoshops.aftership.com"></div>
# <a href="https://goo.gl/Bkt2Uj" target="_blank">
# <div><img src="https://nebula.wsimg.com/obj/RjE0MTAzNDhCNkMzQ0Y1MzE2ODc6MzI1YmZlYzIyNDk3YTEzN2RkYTNlMThhYzRiYmVmZmU6Ojo6OjA=" style="width: 304px;"><br></div></a>
# <script type="text/javascript">
#     window.smartlook||(function(d) {
#     var o=smartlook=function(){ o.api.push(arguments)},h=d.getElementsByTagName('head')[0];
#     var c=d.createElement('script');o.api=new Array();c.async=true;c.type='text/javascript';
#     c.charset='utf-8';c.src='https://rec.smartlook.com/recorder.js';h.appendChild(c);
#     })(document);
#     smartlook('init', '012ad59964ba098eb1064336f00d5d9e40f5f837');
# </script>
# <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2293_original/:/rs=w:800,h:800" style="box-sizing: border-box; border: 0px; max-width: 100%; height: auto;">
# <img src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2147_original/:/rs=w:800,h:800" style="box-sizing: border-box; border: 0px; max-width: 100%; height: auto;">
# <!--Start of Tawk.to Script-->
# <script type="text/javascript">
# var Tawk_API=Tawk_API||{}, Tawk_LoadStart=new Date();
# (function(){
# var s1=document.createElement("script"),s0=document.getElementsByTagName("script")[0];
# s1.async=true;
# s1.src='https://embed.tawk.to/5a0424fc198bd56b8c03a242/default';
# s1.charset='UTF-8';
# s1.setAttribute('crossorigin','*');
# s0.parentNode.insertBefore(s1,s0);
# })();
# </script>
# <!--End of Tawk.to Script-->
# <!-- GetButton.io widget -->
# <script type="text/javascript">
#     (function () {
#         var options = {
#             whatsapp: "+91(9080)749858", // WhatsApp number
#             call_to_action: "Message us", // Call to action
#             position: "left", // Position may be 'right' or 'left'
#         };
#         var proto = document.location.protocol, host = "getbutton.io", url = proto + "//static." + host;
#         var s = document.createElement('script'); s.type = 'text/javascript'; s.async = true; s.src = url + '/widget-send-button/js/init.js';
#         s.onload = function () { WhWidgetSendButton.init(host, proto, options); };
#         var x = document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- /GetButton.io widget -->
#
#
#
#
#
#
#
#
#
#
# <script>
#   (function() {
#     var sa = document.createElement('script'); sa.type = 'text/javascript'; sa.async = true;
#     sa.src = ('https:' == document.location.protocol ? 'https://cdn' : 'http://cdn') + '.ywxi.net/js/1.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sa, s);
#   })();
# </script>
#
#
#
#             <script>
#               "undefined"==typeof _trfd&&(window._trfd=[]),
#               _trfd.push({"tccl.baseHost":"secureserver.net"});
#               _trfd.push({"ap":"OLS"});
#
#             </script>
#             <script src="//img1.wsimg.com/tcc/tcc_l.combined.1.0.6.min.js">
#             </script>
#
#
#
#
# <ins class="adsbygoogle adsbygoogle-noablate" data-adsbygoogle-status="done" style="display: none !important;" data-ad-status="unfilled"><div id="aswift_0_host" tabindex="0" title="Advertisement" aria-label="Advertisement" style="border: none; height: 0px; width: 0px; margin: 0px; padding: 0px; position: relative; visibility: visible; background-color: transparent; display: inline-block;"><iframe id="aswift_0" name="aswift_0" style="left:0;position:absolute;top:0;border:0;width:undefinedpx;height:undefinedpx;" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" frameborder="0" marginwidth="0" marginheight="0" vspace="0" hspace="0" allowtransparency="true" scrolling="no" src="https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2880440375789047&amp;output=html&amp;adk=1812271804&amp;adf=3025194257&amp;lmt=1687359321&amp;plat=1%3A1024%2C2%3A1024%2C3%3A2162688%2C4%3A2162688%2C9%3A32776%2C16%3A8388608%2C17%3A32%2C24%3A32%2C25%3A32%2C30%3A1048576%2C32%3A32%2C41%3A32%2C42%3A32&amp;format=0x0&amp;url=https%3A%2F%2Fyoshops.com%2F&amp;ea=0&amp;pra=5&amp;wgl=1&amp;uach=WyJXaW5kb3dzIiwiMTUuMC4wIiwieDg2IiwiIiwiMTE0LjAuNTczNS4xMzQiLFtdLDAsbnVsbCwiNjQiLFtbIk5vdC5BL0JyYW5kIiwiOC4wLjAuMCJdLFsiQ2hyb21pdW0iLCIxMTQuMC41NzM1LjEzNCJdLFsiR29vZ2xlIENocm9tZSIsIjExNC4wLjU3MzUuMTM0Il1dLDBd&amp;dt=1687359320358&amp;bpp=21&amp;bdt=1480&amp;idt=903&amp;shv=r20230615&amp;mjsv=m202306080101&amp;ptt=9&amp;saldr=aa&amp;abxe=1&amp;nras=1&amp;correlator=3941481459120&amp;frm=20&amp;pv=2&amp;ga_vid=1297572884.1687359320&amp;ga_sid=1687359321&amp;ga_hid=1641288820&amp;ga_fc=1&amp;u_tz=330&amp;u_his=2&amp;u_h=720&amp;u_w=1280&amp;u_ah=672&amp;u_aw=1280&amp;u_cd=24&amp;u_sd=1.5&amp;dmc=8&amp;adx=-12245933&amp;ady=-12245933&amp;biw=1019&amp;bih=520&amp;scr_x=0&amp;scr_y=0&amp;eid=44759876%2C44759927%2C44759837%2C31075308%2C44788441%2C44794790&amp;oid=2&amp;pvsid=850214029144413&amp;tmod=364692653&amp;uas=0&amp;nvt=1&amp;fc=1920&amp;brdim=10%2C10%2C10%2C10%2C1280%2C0%2C1050%2C652%2C1036%2C520&amp;vis=1&amp;rsz=%7C%7Cs%7C&amp;abl=NS&amp;fu=32768&amp;bc=31&amp;ifi=1&amp;uci=a!1&amp;fsb=1&amp;dtd=934" data-google-container-id="a!1" data-load-complete="true"></iframe></div></ins><div id="gb-widget-2876" style="bottom: 14px; left: 16px; opacity: 1; transition: opacity 0.5s ease 0s; box-sizing: border-box; direction: ltr; text-align: left; position: fixed !important; z-index: 16000160 !important;"><div class="q8c6tt-2 fiKefb"><a size="50" href="https://wa.me/919080749858" target="_blank" color="#4dc247" id="getbutton-whatsapp" class="q8c6tt-0 jmDuqF"><svg viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="width: 100%; height: 100%; fill: rgb(255, 255, 255); stroke: none;"><path d="M19.11 17.205c-.372 0-1.088 1.39-1.518 1.39a.63.63 0 0 1-.315-.1c-.802-.402-1.504-.817-2.163-1.447-.545-.516-1.146-1.29-1.46-1.963a.426.426 0 0 1-.073-.215c0-.33.99-.945.99-1.49 0-.143-.73-2.09-.832-2.335-.143-.372-.214-.487-.6-.487-.187 0-.36-.043-.53-.043-.302 0-.53.115-.746.315-.688.645-1.032 1.318-1.06 2.264v.114c-.015.99.472 1.977 1.017 2.78 1.23 1.82 2.506 3.41 4.554 4.34.616.287 2.035.888 2.722.888.817 0 2.15-.515 2.478-1.318.13-.33.244-.73.244-1.088 0-.058 0-.144-.03-.215-.1-.172-2.434-1.39-2.678-1.39zm-2.908 7.593c-1.747 0-3.48-.53-4.942-1.49L7.793 24.41l1.132-3.337a8.955 8.955 0 0 1-1.72-5.272c0-4.955 4.04-8.995 8.997-8.995S25.2 10.845 25.2 15.8c0 4.958-4.04 8.998-8.998 8.998zm0-19.798c-5.96 0-10.8 4.842-10.8 10.8 0 1.964.53 3.898 1.546 5.574L5 27.176l5.974-1.92a10.807 10.807 0 0 0 16.03-9.455c0-5.958-4.842-10.8-10.802-10.8z"></path></svg></a></div></div><script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=xa-533ee0135d741799"></script><script src="//staticw2.yotpo.com/blvTZfFxLLY4ORJETmn8JsqzVHfudrJxLDPnwDXb/widget.js"></script></body><iframe id="google_esf" name="google_esf" src="https://googleads.g.doubleclick.net/pagead/html/r202 ...
# Toys & Games
# Mobiles
# Laptops
# Accessories
# Electronics
# Home & Kitchen
# Fashion
# Foods
# Services
#           Category                     Sub Category  Number of Items
# 0     Toys & Games                     Play Station                7
# 1     Toys & Games                            Drone               19
# 2     Toys & Games                         R C Toys               13
# 3     Toys & Games                        Soft Toys               32
# 4     Toys & Games               Gaming Accessories               48
# 5          Mobiles                    Mobile Phones               48
# 6          Mobiles                      Smartphones                5
# 7          Mobiles                       Headphones               48
# 8          Mobiles               Mobile Accessories               48
# 9          Mobiles              Basic Keypad Phones                9
# 10         Laptops                   Gaming Laptops                5
# 11         Laptops                 Personal Laptops                5
# 12         Laptops                          Tablets                6
# 13         Laptops               Laptop Accessories               48
# 14         Laptops             Computer Accessories               48
# 15     Accessories                            Books               10
# 16     Accessories                       Stationary                3
# 17     Accessories                          Grocery               22
# 18     Accessories                             More               13
# 19     Electronics                           LED TV                9
# 20     Electronics                Jewwlry & Watches               14
# 21  Home & Kitchen                             Iron                3
# 22  Home & Kitchen             Mixer Grinder Juicer               10
# 23         Fashion                              Men               27
# 24         Fashion                            Women               45
# 25         Fashion                             Kids               18
# 26            Food                          Organic               23
# 27            Food                        Vegetable                1
# 28            Food                    Non Vegetable               22
# 29            Food                          Seafood               10
# 30            Food                         Biriyani                8
# 31        Services                           Tution               40
# 32        Services                      Internships               32
# 33        Services           PCD Pharma Distributor                6
# 34        Services            Sponsorship Marketing               14
# 35        Services  Refurbished & Used Laptop Phone                1
# 36        Services                         Banglore               48
# 37        Services                          Chennai               48
# 38        Services                           Mumbai               48
# 39           TOTAL                                               864
# C:\Users\91967\AppData\Local\Temp\ipykernel_16044\3124236238.py:447: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   product_file.save()
